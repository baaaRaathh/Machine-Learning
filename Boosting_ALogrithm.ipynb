# %% [markdown]
# <a href="https://colab.research.google.com/github/baaaRaathh/Machine-Learning/blob/main/Boosting_ALogrithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree  import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
df['Systoic'] = df['Blood Pressure'].str.split('/').str[0].astype(int)
df['Distolic'] = df['Blood Pressure'].str.split('/').str[1].astype(int)
df.drop(['Blood Pressure','Person ID'],axis=1,inplace=True)

# %%
x = df.drop(['Sleep Disorder'],axis=1)
y = df['Sleep Disorder']

# %%
df['Sleep Disorder'].unique()
# Out:
# array(['None', 'Sleep Apnea', 'Insomnia'], dtype=object)

# %%
y.fillna(value='None',inplace=True)

# %%
x
# Out:
#      Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0      Male   27     Software Engineer             6.1                 6
# 1      Male   28                Doctor             6.2                 6
# 2      Male   28                Doctor             6.2                 6
# 3      Male   28  Sales Representative             5.9                 4
# 4      Male   28  Sales Representative             5.9                 4
# ..      ...  ...                   ...             ...               ...
# 369  Female   59                 Nurse             8.1                 9
# 370  Female   59                 Nurse             8.0                 9
# 371  Female   59                 Nurse             8.1                 9
# 372  Female   59                 Nurse             8.1                 9
# 373  Female   59                 Nurse             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# ...

# %%
column = ['Gender'	,'Age',	'Occupation',	'Sleep Duration'	,'Quality of Sleep',	'Physical Activity Level'	,'Stress Level',	'BMI Category',	'Heart Rate',	'Daily Steps' ,	'Systoic'	,'Distolic']
for i in column:
  la = LabelEncoder()
  x[i] =la.fit_transform(x[i])

# %%
y = la.fit_transform(y)

# %%
# Out:
#      Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0         1    0           9               3                 2
# 1         1    1           1               4                 2
# 2         1    1           1               4                 2
# 3         1    1           6               1                 0
# 4         1    1           6               1                 0
# ..      ...  ...         ...             ...               ...
# 369       0   30           5              22                 5
# 370       0   30           5              21                 5
# 371       0   30           5              22                 5
# 372       0   30           5              22                 5
# 373       0   30           5              22                 5
#
#      Physical Activity Level  Stress Level  BMI Category  Heart Rate  \
# 0                          4             3             3          10
# ...

# %%
import numpy as np

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
np.unique(y_test)
# Out:
# array([0, 1, 2])

# %%
model = DecisionTreeClassifier(criterion='entropy',max_depth=1)

# %%
adabosst = AdaBoostClassifier(base_estimator= model ,n_estimators=400,learning_rate=1)

# %%
ada = adabosst.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
ob = [[1,2,2,33,4,4,5,74,73,8,1,2]]

# %%
c=ada.predict(x_test)
for i in c:
  if i == 0:
    print('None')
  elif i == 1:
    print('Sleep Apnea')
  elif i == 2:
    print('Insomnia')
# Out:
# None
# Sleep Apnea
# Sleep Apnea
# Insomnia
# Sleep Apnea
# Insomnia
# Sleep Apnea
# Sleep Apnea
# Insomnia
# None
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Insomnia
# Sleep Apnea
# None
# Sleep Apnea
# Sleep Apnea
# Insomnia
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Insomnia
# Sleep Apnea
# Insomnia
# None
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Insomnia
# Insomnia
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# None
# Sleep Apnea
# Insomnia
# None
# Sleep Apnea
# Sleep Apnea
# None
# Insomnia
# Sleep Apnea
# None
# Insomnia
# Sleep Apnea
# Insomnia
# Sleep Apnea
# Sleep Apnea
# None
# Sleep Apnea
# None
# Sleep Apnea
# Sleep Apnea
# Insomnia
# None
# Insomnia
# Insomnia
# None
# Sleep Apnea
# Insomnia
# None
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# Sleep Apnea
# None
# Sleep Apnea
# Insomnia
# ...

# %%
p = metrics.accuracy_score(y_test,c)

# %%
p
# Out:
# 0.8053097345132744

# %% [markdown]
# <a href="https://colab.research.google.com/github/baaaRaathh/Machine-Learning/blob/main/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pydataset import data
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 82.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939416 sha256=4cca3fcaf5a210d8817a01dfa1552aea2cd46601b30be231ad371d815cff24c2
#   Stored in directory: /root/.cache/pip/wheels/2b/83/5c/073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# ...

# %%
df = data('DoctorAUS')
df
# Out:
#       sex   age  income insurance  illness  actdays  hscore chcond  doctorco  nondocco  hospadmi  \
# 1       1  0.19    0.55  levyplus        1        4       1     np         1         0         0
# 2       1  0.19    0.45  levyplus        1        2       1     np         1         0         0
# 3       0  0.19    0.90   medlevy        3        0       0     np         1         0         1
# 4       0  0.19    0.15   medlevy        1        0       0     np         1         0         0
# 5       0  0.19    0.45   medlevy        2        5       1     la         1         0         0
# ...   ...   ...     ...       ...      ...      ...     ...    ...       ...       ...       ...
# 5186    1  0.22    0.55   medlevy        0        0       0     np         0         0         0
# 5187    0  0.27    1.30   medlevy        0        0       1     np         0         0         0
# 5188    1  0.37    0.25  freerepa        1        0       1     np         0         0         0
# ...

# %%
df.dtypes
# Out:
# sex            int64
# age          float64
# income       float64
# insurance     object
# illness        int64
# actdays        int64
# hscore         int64
# chcond        object
# doctorco       int64
# nondocco       int64
# hospadmi       int64
# hospdays       int64
# medecine       int64
# prescrib       int64
# nonpresc       int64
# dtype: object

# %%
x = df.drop(['insurance','chcond'],axis=1)
y = df['insurance']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
nb = GaussianNB().fit(x_train,y_train)

# %%
h = nb.predict(x_test)

# %%
print(classification_report(y_test,h))
# Out:
#               precision    recall  f1-score   support
#
#      freepor       0.22      0.05      0.08        44
#     freerepa       0.66      0.52      0.58       221
#     levyplus       0.47      0.31      0.38       431
#      medlevy       0.49      0.80      0.61       342
#
#     accuracy                           0.51      1038
#    macro avg       0.46      0.42      0.41      1038
# weighted avg       0.51      0.51      0.48      1038
